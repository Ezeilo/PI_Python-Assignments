# %% [markdown]
# # Assignment 1 BY:
# ### Ezeilo Chibuzor Victoria

# %%
#My biodata
Name = "Ezeilo Chibuzor Victoria"
Age = "23 yrs old"
Country = "Nigeria"
State_of_Origin = "Anambra"
Height = "not certain"
Weight = "50 kg"
Profession = "Medicine"
Future_Path = "Data Analysis"
Hobby = "Reading"
Has_laptop = True

# %%
print("My name is",Name)
print("I am from",State_of_Origin)
print("My country is",Country)
print("I am",Age)
print("I am", Height,"of  my height")
print("I weigh",Weight)
print(Profession, "is my profession")
print("I will pursue", Future_Path)
print(Hobby, "is my hobby")
print("It is",Has_laptop, "that I have a laptop")
# Out:
# My name is Ezeilo Chibuzor Victoria
# I am from Anambra
# My country is Nigeria
# I am 23 yrs old
# I am Not certain of  my height
# I weigh 50 kg
# Medicine is my profession
# I will pursue Data Analysis
# Reading is my hobby
# It is True that I have a laptop
