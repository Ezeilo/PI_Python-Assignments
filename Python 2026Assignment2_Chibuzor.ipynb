# %% [markdown]
# # Assignment 2
# ### Input,Output,Errors & Operators
# **By:** Ezeilo Chibuzor Victoria

# %%
Full_Name = input("Enter your fullname")
Age = input("How old are you?")
Country = input("What country are you from?")
Height = input("Enter your height in meters")
Programming_status = input("Are you a programmer or not?(True or False)")

print(f"My name is {Full_Name}")
print(f"I am {Age} years old")
print(f"I am from {Country}")
print(f"I am {Height} meters tall")
print(f"It is {Programming_status} that I am a programmer")
# Out:
# Enter your fullname Chibuzor
# How old are you? 23
# What country are you from? Nigeria
# Enter your height in meters 1.56
# Are you a programmer or not?(True or False) True
# My name is Chibuzor
# I am 23 years old
# I am from Nigeria
# I am 1.56 meters tall
# It is True that I am a programmer

# %%
type(Full_Name)
type(Age)
type(Country)
type(Height)
type(Programming_status)

print(type(Full_Name))
print(type(Age))
print(type(Country))
print(type(Height))
print(type(Programming_status))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
age = input("Enter your age:")
print("Next year you will be " + age + 1)
# Out:
# Enter your age: 23
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 age = input("Enter your age:")
# ----> 2 print("Next year you will be " + age + 1)
#
# TypeError: can only concatenate str (not "int") to str

# %%
age= int(input("Enter your age:"))
print(f"Next year you will be {age+1}")
# Out:
# Enter your age: 23
# Next year you will be 24

# %%
age = 20
if age>18:
print("You are eligible to vote")
# Out:
#   Cell In[3], line 3
#     print("You are eligible to vote")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
age= 20
if age>18:
    print("You are eligible to vote")
# Out:
# You are eligible to vote

# %%
a = 10
b = 3

print(a + b, "addition")
print(a - b,"subtraction") 
print(a * b,"multiplication")
print(a/b,"True division")
print(a//b,"Floor division")
print(a%b,"Modulus")
print(a**b,"Exponential")
# Out:
# 13 addition
# 7 subtraction
# 30 multiplication
# 3.3333333333333335 True division
# 3 Floor division
# 1 Modulus
# 1000 Exponential

# %%
#Comparison Opertors

x = 15
y = 20
print(x==y)
print(x!=y)
print(x>y)
print(x<y)
print(x>=25)
print(y<=25)
# Out:
# False
# True
# False
# True
# False
# True

# %%
#Logical Operators

age = 22
has_id =  True
print(age>=18 and has_id)
print(age<18 or has_id)
print(not has_id)
# Out:
# True
# True
# False

# %%
a = [1,2,3]
b = [1,2,3]
c  = a
print(a is b)
print(a==b)
print(a is c)
print(a is not b)
# Out:
# False
# True
# True
# True
